# %%
import pandas as pd
import re

# %%
years = ['1999', '2001', '2003', '2005', '2007',
         '2009', '2011', '2013', '2015', '2017', 
         '2019', '2000', '2002', '2004', '2006',
         '2008', '2010', '2012', '2014', '2016', 
         '2018']

# %% [markdown]
# Look below for how I went about fixing this.

# %%
opinion_option_file = open('opinion_options_file.txt', 'r')
opinion_options = []
for each_line in opinion_option_file:
    opinion_options.append(each_line.strip())
opinion_option_file.close()

# %% [markdown]
# THERE'S SOME WEIRD STUFF LIKE #=72 IN 2018...GO BACK AND FIX THIS...

# %%
df_dict = {}
full_dict_of_opinion_strings = {}
for eachYear in years: 
    file_2019 = open('./raw_wiki_data/%s.txt' % str(eachYear), 'r')

    current_case = 0
    justice_info = {}
    justice_df = pd.DataFrame()
    for each_line in file_2019:
        ###### FIX THIS PART TO FIX THE JUSTICES
        # Getting the justices:
        if 'SCOTUS-termlist-start' in each_line:
            justices_info = each_line.strip().strip('}}').split('|')[1:]
            justices_info = [item.lower().replace(' ', '') for item in justices_info]
            justice_df = pd.DataFrame(columns=justices_info)

        # If you hit this, that means you're on a new case:
        if '#=' in each_line:
            # Updating the iterator:
            previous_case = current_case
            current_case += 1
            # If you don't have any justice info yet, continue
            if len(justice_info.keys()) == 0:
                continue
            # Otherwise, make a df out of that info:
            temp_df = pd.DataFrame.from_dict(justice_info)
            justice_df = justice_df.append(temp_df)
            # Reset the dict:
            justice_info = {}

        # If there's no justice info, fuggetaboutit
        if '|justice' not in each_line:
            continue

        ###### FIX THIS PART TO FIX THE OPINIONS
        # Otherwise...
        else:
            # Start by getting the justice:
            justice_list = each_line.split('--')
            justice = justice_list[1].replace(' not yet appointed', '').replace('retired', '').strip()
            # Get the opinion:
            # This is the former method of doing this:
#             opinion = justice_list[0].split('=')[1].split(' |')[0].replace(' not yet appointed', '').replace('retired', '').strip()
            # Now I iterate over the possible opinions, get all the ones present:
            opinions_present = []
            for each_option in opinion_options:
                if each_option in justice_list[0]:
                    opinions_present.append(each_option)
            opinions_present.sort()
            final_opinion_string = ' '.join(opinions_present)
            try:
                full_dict_of_opinion_strings[final_opinion_string] += 1
            except:
                full_dict_of_opinion_strings[final_opinion_string] = 1
            justice_info[justice.lower()] = [final_opinion_string]

    justice_df.to_excel('./parsed_wiki_data/%s.xlsx' % str(eachYear))
    df_dict[eachYear] = justice_df

# %% [markdown]
# Right now, I'm doing splitting...instead, I'm going to get all possible strings, and pattern match:

# %%
all_combined = []
for each_year in df_dict.keys():
    for each_column in df_dict[each_year]:
        temp_column_val = list(set([re.sub(r'\d+', '', item) for item in list(set(df_dict[each_year][each_column]))]))
        all_combined = all_combined + temp_column_val

# %%
# Cleaning up the all_combined, and using that to determine what the judges did:
print(len(all_combined))
all_combined = list(set(all_combined))
cleaned_all_combined_v1 = [re.sub(r'\d+', '', item) for item in all_combined]
cleaned_all_combined_v2 = [item.split('|')[0] for item in cleaned_all_combined_v1]
cleaned_all_combined_v3 = list(set(cleaned_all_combined_v2))
print(len(cleaned_all_combined_v3))
# Out:
# 1515
# 19

# %%
cleaned_all_combined_v3
# Out:
# ['didnotparticipate',
#  'concurrencedissentwithoutopinion',
#  'partjoinmajority',
#  'majority',
#  'concurrence',
#  'partjoinconcurrence',
#  'joinplurality',
#  'partjoinplurality',
#  'dissentwithoutopinion',
#  'dissent',
#  'concurrencedissent',
#  'concurrencewithoutopinion',
#  'joinconcurrencedissent',
#  'joinmajority',
#  'plurality',
#  'joinconcurrence',
#  'partjoindissent',
#  'partjoinconcurrencedissent',
#  'joindissent']

# %%
opinion_options_file = open('opinion_options_file.txt', 'w')
for each_type in cleaned_all_combined_v3:
    opinion_options_file.write(each_type + '\n')
opinion_options_file.close()

# %%
df_dict['2018']
# Out:
#                                               roberts  \
# 0                               majority joinmajority
# 0                                            majority
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# ..                                                ...
# 0                               majority joinmajority
# 0   partjoinmajority majority concurrence joinmajo...
# 0                                 dissent joindissent
# 0                                            majority
# 0                                            majority
#
#                                                thomas  \
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# ..                                                ...
# 0                                 dissent joindissent
# 0                         concurrence joinconcurrence
# 0                                 dissent joindissent
# 0                               majority joinmajority
# 0   partjoinmajority majority concurrence dissent ...
#
#                                              ginsburg  \
# 0                                            majority
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# ..                                                ...
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                                 dissent joindissent
# 0   partjoinmajority majority concurrence dissent ...
#
#                                                breyer  \
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                                            majority
# 0                               majority joinmajority
# 0                               majority joinmajority
# ..                                                ...
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                                         concurrence
# 0                                 dissent joindissent
# 0   partjoinmajority majority concurrence dissent ...
#
#                                                 alito  \
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# ..                                                ...
# 0                                            majority
# 0     concurrence partjoinconcurrence joinconcurrence
# 0                                             dissent
# 0                               majority joinmajority
# 0   partjoinmajority majority concurrence dissent ...
#
#                                             sotomayor  \
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# ..                                                ...
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                                 dissent joindissent
# 0   partjoinmajority majority concurrence dissent ...
#
#                                                 kagan  \
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# ..                                                ...
# 0                               majority joinmajority
# 0                                           plurality
# 0                               majority joinmajority
# 0                                             dissent
# 0   partjoinmajority majority concurrence dissent ...
#
#                                               gorsuch  \
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# ..                                                ...
# 0                                             dissent
# 0                                         concurrence
# 0                                           plurality
# 0                               majority joinmajority
# 0   partjoinmajority majority concurrence dissent ...
#
#                                             kavanaugh
# 0                                   didnotparticipate
# 0                                   didnotparticipate
# 0                               majority joinmajority
# 0                               majority joinmajority
# 0                               majority joinmajority
# ..                                                ...
# 0                               majority joinmajority
# 0     concurrence partjoinconcurrence joinconcurrence
# 0                                 dissent joindissent
# 0                               majority joinmajority
# 0   partjoinmajority majority concurrence dissent ...
#
# [72 rows x 9 columns]

# %% [markdown]
# Also writing out the full list of opinion strings:

# %%
sorted_full_dict_of_opinion_strings = {k: v for k, v in sorted(full_dict_of_opinion_strings.items(), key=lambda item: item[1], reverse=True)}

# %%
sorted_full_dict_of_opinion_strings
# Out:
# {'joinmajority majority': 9090,
#  'majority': 1330,
#  'dissent joindissent': 1283,
#  'dissent': 901,
#  'concurrence joinmajority majority': 438,
#  'didnotparticipate': 361,
#  'concurrence': 320,
#  'concurrence joinconcurrence joinmajority majority': 241,
#  'concurrence joinconcurrence': 159,
#  'concurrence joinmajority majority partjoinmajority': 119,
#  'dissent joindissent partjoindissent': 108,
#  'plurality': 106,
#  'concurrence concurrencedissent dissent joinconcurrence joinconcurrencedissent joinmajority majority partjoinmajority': 83,
#  'concurrence concurrencedissent dissent joinmajority majority partjoinmajority': 77,
#  'joinmajority majority partjoinmajority': 70,
#  'concurrence concurrencedissent dissent': 70,
#  'concurrence concurrencedissent dissent joinconcurrence joinconcurrencedissent': 65,
#  'concurrence joinconcurrence joinmajority majority partjoinmajority': 53,
#  'joinplurality plurality': 18,
#  'concurrence concurrencedissent dissent joinconcurrence joinconcurrencedissent joinmajority majority partjoinconcurrence partjoinconcurrencedissent partjoinmajority': 18,
#  'concurrence joinconcurrence joinmajority majority partjoinconcurrence': 12,
#  'dissent dissentwithoutopinion': 12,
#  'joinmajority joinplurality majority plurality': 9,
#  'concurrence joinconcurrence partjoinconcurrence': 8,
#  'concurrence joinconcurrence joinmajority majority partjoinconcurrence partjoinmajority': 7,
#  'concurrence concurrencedissent dissent joinconcurrence joinconcurrencedissent partjoinconcurrence partjoinconcurrencedissent': 4,
#  'concurrence concurrencewithoutopinion': 4,
#  'dissent joindissent joinmajority majority': 4,
#  'majority plurality': 3,
#  'dissent joindissent joinmajority majority partjoinmajority': 3,
#  'dissent joindissent joinmajority majority partjoindissent partjoinmajority': 3,
#  'concurrence concurrencedissent dissent joinmajority majority': 2,
#  'concurrence dissent joindissent partjoindissent': 2,
#  'concurrence concurrencedissent dissent joindissent joinmajority majority partjoindissent partjoinmajority': 2,
#  'dissent majority': 2,
#  'concurrence concurrencedissent dissent joinconcurrence joinconcurrencedissent joindissent': 1,
#  'concurrence concurrencedissent dissent joinconcurrence joinconcurrencedissent joinmajority majority': 1,
#  'concurrence concurrencedissent dissent joinconcurrence joinconcurrencedissent joindissent partjoinconcurrence partjoinconcurrencedissent partjoindissent': 1,
#  'concurrence concurrencedissent dissent joinconcurrence joinconcurrencedissent joinmajority majority partjoinconcurrence partjoinconcurrencedissent': 1,
#  'concurrence concurrencedissent dissent joinconcurrence joinconcurrencedissent majority': 1,
#  'dissent joinmajority majority partjoinmajority': 1,
#  'concurrence concurrencedissent dissent joinconcurrence joinconcurrencedissent joindissent joinmajority majority partjoinconcurrence partjoinconcurrencedissent': 1,
#  'concurrence concurrencedissent dissent joindissent joinmajority majority': 1,
#  'concurrence concurrencedissent dissent joinconcurrence joinmajority majority partjoinconcurrence partjoinmajority': 1,
#  'concurrence joinconcurrence joinplurality partjoinconcurrence partjoinplurality plurality': 1,
#  'concurrence dissent joinconcurrence partjoinconcurrence': 1,
#  'concurrence joinplurality plurality': 1,
#  'concurrence dissent joinconcurrence joindissent partjoinconcurrence': 1,
#  'concurrence concurrencedissent dissent joinconcurrence joinconcurrencedissent joindissent partjoinconcurrence partjoinconcurrencedissent': 1,
#  'concurrence dissent joinconcurrence joindissent partjoinconcurrence partjoindissent': 1,
#  'concurrence concurrencedissent dissent joinconcurrence joinconcurrencedissent joindissent joinmajority majority partjoinconcurrence partjoinconcurrencedissent partjoinmajority': 1,
#  'concurrence concurrencedissent dissent joinconcurrence joinconcurrencedissent joindissent joinmajority majority partjoinmajority': 1,
#  'dissent joindissent joinmajority majority partjoindissent': 1,
#  'dissent joinmajority majority': 1,
#  'concurrence concurrencedissent concurrencedissentwithoutopinion dissent dissentwithoutopinion': 1}

# %%
full_opinion_file = open('full_opinion_list.txt', 'w')
for each_opinion in sorted_full_dict_of_opinion_strings.keys():
    full_opinion_file.write(each_opinion + '\t' + str(sorted_full_dict_of_opinion_strings[each_opinion]) + '\n')
full_opinion_file.close()
